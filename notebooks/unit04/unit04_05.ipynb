# %% [markdown]
# This notebook was prepared by Cayetano Benavent, 2016.

# %% [markdown]
# # Matplotlib: plotting 03

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Histograms

# %% [markdown]
# Building histograms:

# %%
mean = 500
std = 50
size = 1000
data = np.random.normal(loc=mean, scale=std, size=size)

# %%
plt.hist(data)
plt.title("Histogram")
plt.xlabel("Data")
plt.ylabel("Freq")

# %% [markdown]
# Personalizing color and number of bins:

# %%
n_bins = 20
plt.hist(data, n_bins, facecolor='green', alpha=0.5)
plt.title("Histogram")
plt.xlabel("Data")
plt.ylabel("Freq")

# %%
n_bins = 20
plt.hist(data, n_bins, normed=1, facecolor='green', alpha=0.5)
plt.title("Histogram")
plt.xlabel("Data")
plt.ylabel("Freq")

# %% [markdown]
# Adding a line showing the expected distribution:

# %%
import matplotlib.mlab as mlab

n_bins = 20
n, bins, patches = plt.hist(data, n_bins, normed=1, facecolor='green', alpha=0.5)
print(bins)
y = mlab.normpdf(bins, mean, std)
l = plt.plot(bins, y, 'r--', linewidth=1.5)
plt.title("Histogram")
plt.xlabel("Data")
plt.ylabel("Freq")
plt.subplots_adjust(left=0.15)
# Out:
# [ 345.76846443  363.07424839  380.38003235  397.68581631  414.99160026
#   432.29738422  449.60316818  466.90895214  484.2147361   501.52052006
#   518.82630402  536.13208798  553.43787194  570.7436559   588.04943986
#   605.35522382  622.66100777  639.96679173  657.27257569  674.57835965
#   691.88414361]
